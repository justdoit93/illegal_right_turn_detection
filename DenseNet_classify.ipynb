# %%
import pandas as pd
import numpy as np

# CSV 파일을 DataFrame으로 가져오기
train_data = pd.read_csv('./Data/train_df.csv')
train_data = pd.DataFrame(train_data)
train_data
# Out:
#              image_name                           image_path class  label
# 0        SUV_2008-1.jpg   ./Data/Training/승용차/SUV_2008-1.jpg   승용차      0
# 1       SUV_2008-10.jpg  ./Data/Training/승용차/SUV_2008-10.jpg   승용차      0
# 2       SUV_2008-11.jpg  ./Data/Training/승용차/SUV_2008-11.jpg   승용차      0
# 3       SUV_2008-12.jpg  ./Data/Training/승용차/SUV_2008-12.jpg   승용차      0
# 4       SUV_2008-13.jpg  ./Data/Training/승용차/SUV_2008-13.jpg   승용차      0
# ...                 ...                                  ...   ...    ...
# 397763      특수_기타-4.jpg      ./Data/Training/승합차/특수_기타-4.jpg   승합차      1
# 397764      특수_기타-5.jpg      ./Data/Training/승합차/특수_기타-5.jpg   승합차      1
# 397765      특수_기타-6.jpg      ./Data/Training/승합차/특수_기타-6.jpg   승합차      1
# 397766      특수_기타-8.jpg      ./Data/Training/승합차/특수_기타-8.jpg   승합차      1
# 397767      특수_기타-9.jpg      ./Data/Training/승합차/특수_기타-9.jpg   승합차      1
#
# [397768 rows x 4 columns]

# %%
# index 343303 부터 승합차
dataset_van = train_data.iloc[343303:]
dataset_van
# Out:
#          image_name                       image_path class  label
# 343303     버스-1.jpg     ./Data/Training/승합차/버스-1.jpg   승합차      1
# 343304     버스-2.jpg     ./Data/Training/승합차/버스-2.jpg   승합차      1
# 343305     버스-3.jpg     ./Data/Training/승합차/버스-3.jpg   승합차      1
# 343306     버스-4.jpg     ./Data/Training/승합차/버스-4.jpg   승합차      1
# 343307     버스-5.jpg     ./Data/Training/승합차/버스-5.jpg   승합차      1
# ...             ...                              ...   ...    ...
# 397763  특수_기타-4.jpg  ./Data/Training/승합차/특수_기타-4.jpg   승합차      1
# 397764  특수_기타-5.jpg  ./Data/Training/승합차/특수_기타-5.jpg   승합차      1
# 397765  특수_기타-6.jpg  ./Data/Training/승합차/특수_기타-6.jpg   승합차      1
# 397766  특수_기타-8.jpg  ./Data/Training/승합차/특수_기타-8.jpg   승합차      1
# 397767  특수_기타-9.jpg  ./Data/Training/승합차/특수_기타-9.jpg   승합차      1
#
# [54465 rows x 4 columns]

# %%
a = list(range(0, 50))

# %%
numbers = np.random.choice(range(0, 343303), 50000, replace=False)
numbers = list(numbers)

# %%
# train 승용차 데이터에서 랜덤으로 numbers 수만큼 데이터 뽑아서 데이터프레임 생성
dataset_random = {"image_name": [], "image_path": [], "class": [], "label": []}
for i in numbers:
    dataset_random['image_name'].append(train_data.iloc[i, 0])
    dataset_random['image_path'].append(train_data.iloc[i, 1])
    dataset_random['class'].append(train_data.iloc[i, 2])
    dataset_random['label'].append(train_data.iloc[i, 3])

dataset_random = pd.DataFrame(dataset_random)
dataset_random
# Out:
#               image_name                             image_path class  label
# 0         해치백_모닝-651.jpg     ./Data/Training/승용차/해치백_모닝-651.jpg   승용차      0
# 1        SUV_엑티언-433.jpg    ./Data/Training/승용차/SUV_엑티언-433.jpg   승용차      0
# 2         세단_SM7-486.jpg     ./Data/Training/승용차/세단_SM7-486.jpg   승용차      0
# 3       세단_쏘나타-43040.jpg   ./Data/Training/승용차/세단_쏘나타-43040.jpg   승용차      0
# 4        세단_K5-13153.jpg    ./Data/Training/승용차/세단_K5-13153.jpg   승용차      0
# ...                  ...                                    ...   ...    ...
# 49995     세단_K3-3365.jpg     ./Data/Training/승용차/세단_K3-3365.jpg   승용차      0
# 49996  SUV_싼타페-14755.jpg  ./Data/Training/승용차/SUV_싼타페-14755.jpg   승용차      0
# 49997   SUV_QM6-3000.jpg   ./Data/Training/승용차/SUV_QM6-3000.jpg   승용차      0
# 49998     세단_K5-8828.jpg     ./Data/Training/승용차/세단_K5-8828.jpg   승용차      0
# 49999   해치백_아이오닉-435.jpg   ./Data/Training/승용차/해치백_아이오닉-435.jpg   승용차      0
#
# [50000 rows x 4 columns]

# %%
train_data = pd.concat([dataset_random,dataset_van], ignore_index=True)
train_data
# Out:
#               image_name                            image_path class  label
# 0         해치백_모닝-651.jpg    ./Data/Training/승용차/해치백_모닝-651.jpg   승용차      0
# 1        SUV_엑티언-433.jpg   ./Data/Training/승용차/SUV_엑티언-433.jpg   승용차      0
# 2         세단_SM7-486.jpg    ./Data/Training/승용차/세단_SM7-486.jpg   승용차      0
# 3       세단_쏘나타-43040.jpg  ./Data/Training/승용차/세단_쏘나타-43040.jpg   승용차      0
# 4        세단_K5-13153.jpg   ./Data/Training/승용차/세단_K5-13153.jpg   승용차      0
# ...                  ...                                   ...   ...    ...
# 104460       특수_기타-4.jpg       ./Data/Training/승합차/특수_기타-4.jpg   승합차      1
# 104461       특수_기타-5.jpg       ./Data/Training/승합차/특수_기타-5.jpg   승합차      1
# 104462       특수_기타-6.jpg       ./Data/Training/승합차/특수_기타-6.jpg   승합차      1
# 104463       특수_기타-8.jpg       ./Data/Training/승합차/특수_기타-8.jpg   승합차      1
# 104464       특수_기타-9.jpg       ./Data/Training/승합차/특수_기타-9.jpg   승합차      1
#
# [104465 rows x 4 columns]

# %%
train_data.to_csv('./Data/train_data.csv', index=False)

# %%
# test CSV 파일을 DataFrame으로 가져오기
test_data = pd.read_csv('./Data/test_df.csv')
test_data = pd.DataFrame(test_data)
test_data
# Out:
#             image_name                       image_path class  label
# 0       SUV_GV80-1.jpg   ./Data/Test/승용차/SUV_GV80-1.jpg   승용차      0
# 1      SUV_GV80-10.jpg  ./Data/Test/승용차/SUV_GV80-10.jpg   승용차      0
# 2      SUV_GV80-11.jpg  ./Data/Test/승용차/SUV_GV80-11.jpg   승용차      0
# 3      SUV_GV80-12.jpg  ./Data/Test/승용차/SUV_GV80-12.jpg   승용차      0
# 4      SUV_GV80-13.jpg  ./Data/Test/승용차/SUV_GV80-13.jpg   승용차      0
# ...                ...                              ...   ...    ...
# 45624   트럭_카고트럭-95.jpg   ./Data/Test/승합차/트럭_카고트럭-95.jpg   승합차      1
# 45625   트럭_카고트럭-96.jpg   ./Data/Test/승합차/트럭_카고트럭-96.jpg   승합차      1
# 45626   트럭_카고트럭-97.jpg   ./Data/Test/승합차/트럭_카고트럭-97.jpg   승합차      1
# 45627   트럭_카고트럭-98.jpg   ./Data/Test/승합차/트럭_카고트럭-98.jpg   승합차      1
# 45628   트럭_카고트럭-99.jpg   ./Data/Test/승합차/트럭_카고트럭-99.jpg   승합차      1
#
# [45629 rows x 4 columns]

# %%
# index 39385 부터 승합차
dataset_van_test = test_data.iloc[39385:]
dataset_van_test
# Out:
#            image_name                      image_path class  label
# 39385     버스_대형-1.jpg     ./Data/Test/승합차/버스_대형-1.jpg   승합차      1
# 39386    버스_대형-10.jpg    ./Data/Test/승합차/버스_대형-10.jpg   승합차      1
# 39387   버스_대형-100.jpg   ./Data/Test/승합차/버스_대형-100.jpg   승합차      1
# 39388   버스_대형-101.jpg   ./Data/Test/승합차/버스_대형-101.jpg   승합차      1
# 39389   버스_대형-102.jpg   ./Data/Test/승합차/버스_대형-102.jpg   승합차      1
# ...               ...                             ...   ...    ...
# 45624  트럭_카고트럭-95.jpg  ./Data/Test/승합차/트럭_카고트럭-95.jpg   승합차      1
# 45625  트럭_카고트럭-96.jpg  ./Data/Test/승합차/트럭_카고트럭-96.jpg   승합차      1
# 45626  트럭_카고트럭-97.jpg  ./Data/Test/승합차/트럭_카고트럭-97.jpg   승합차      1
# 45627  트럭_카고트럭-98.jpg  ./Data/Test/승합차/트럭_카고트럭-98.jpg   승합차      1
# 45628  트럭_카고트럭-99.jpg  ./Data/Test/승합차/트럭_카고트럭-99.jpg   승합차      1
#
# [6244 rows x 4 columns]

# %%
numbers_test = np.random.choice(range(0, 39385), 6000, replace=False)
numbers_test = list(numbers_test)

# %%
# test 데이터에서 랜덤으로 numbers_test 수만큼 데이터 뽑아서 데이터프레임 생성
dataset_random_test = {"image_name": [], "image_path": [], "class": [], "label": []}
for i in numbers_test:
    dataset_random_test['image_name'].append(test_data.iloc[i, 0])
    dataset_random_test['image_path'].append(test_data.iloc[i, 1])
    dataset_random_test['class'].append(test_data.iloc[i, 2])
    dataset_random_test['label'].append(test_data.iloc[i, 3])

dataset_random_test = pd.DataFrame(dataset_random_test)
dataset_random_test
# Out:
#             image_name                        image_path class  label
# 0      세단_쏘나타-5157.jpg   ./Data/Test/승용차/세단_쏘나타-5157.jpg   승용차      0
# 1     화물_기아_봉고-626.jpg  ./Data/Test/승용차/화물_기아_봉고-626.jpg   승용차      0
# 2     SUV_쏘렌토-1270.jpg  ./Data/Test/승용차/SUV_쏘렌토-1270.jpg   승용차      0
# 3     SUV_싼타페-1930.jpg  ./Data/Test/승용차/SUV_싼타페-1930.jpg   승용차      0
# 4      SUV_트렉스-177.jpg   ./Data/Test/승용차/SUV_트렉스-177.jpg   승용차      0
# ...                ...                               ...   ...    ...
# 5995   세단_그랜저-2887.jpg   ./Data/Test/승용차/세단_그랜저-2887.jpg   승용차      0
# 5996    세단_SM5-865.jpg    ./Data/Test/승용차/세단_SM5-865.jpg   승용차      0
# 5997    해치백_레이-554.jpg    ./Data/Test/승용차/해치백_레이-554.jpg   승용차      0
# 5998   세단_쏘나타-1238.jpg   ./Data/Test/승용차/세단_쏘나타-1238.jpg   승용차      0
# 5999     세단_G70-30.jpg     ./Data/Test/승용차/세단_G70-30.jpg   승용차      0
#
# [6000 rows x 4 columns]

# %%
test_data = pd.concat([dataset_random_test,dataset_van_test], ignore_index=True)
test_data
# Out:
#              image_name                        image_path class  label
# 0       세단_쏘나타-5157.jpg   ./Data/Test/승용차/세단_쏘나타-5157.jpg   승용차      0
# 1      화물_기아_봉고-626.jpg  ./Data/Test/승용차/화물_기아_봉고-626.jpg   승용차      0
# 2      SUV_쏘렌토-1270.jpg  ./Data/Test/승용차/SUV_쏘렌토-1270.jpg   승용차      0
# 3      SUV_싼타페-1930.jpg  ./Data/Test/승용차/SUV_싼타페-1930.jpg   승용차      0
# 4       SUV_트렉스-177.jpg   ./Data/Test/승용차/SUV_트렉스-177.jpg   승용차      0
# ...                 ...                               ...   ...    ...
# 12239    트럭_카고트럭-95.jpg    ./Data/Test/승합차/트럭_카고트럭-95.jpg   승합차      1
# 12240    트럭_카고트럭-96.jpg    ./Data/Test/승합차/트럭_카고트럭-96.jpg   승합차      1
# 12241    트럭_카고트럭-97.jpg    ./Data/Test/승합차/트럭_카고트럭-97.jpg   승합차      1
# 12242    트럭_카고트럭-98.jpg    ./Data/Test/승합차/트럭_카고트럭-98.jpg   승합차      1
# 12243    트럭_카고트럭-99.jpg    ./Data/Test/승합차/트럭_카고트럭-99.jpg   승합차      1
#
# [12244 rows x 4 columns]

# %%
test_data.to_csv('./Data/test_data.csv', index=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, TensorDataset
import os

from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
import numpy as np
from torchsummary import summary
import time
import copy

# %%
# 이미지 파일 경로를 포함한 DataFrame 생성
train_path = train_data[['image_path']]

transform = transforms.Compose([
    transforms.Resize((128, 128)),  # 이미지 크기 조정
    transforms.ToTensor(),  # 이미지를 텐서로 변환
    transforms.Normalize(mean=[0.25, 0.25, 0.25], std=[0.1, 0.1, 0.1])  # 이미지 정규화
])

tensor_list_train = []
tensor_list_test = []
for image_path in train_path['image_path']:
    image = Image.open(image_path)
    tensor = transform(image)
    tensor_list_train.append(tensor)

image_tensors_train = torch.stack(tensor_list_train) #train데이터
    
# 이미지 파일 경로를 포함한 DataFrame 생성
test_path = test_data[['image_path']]

transform = transforms.Compose([
    transforms.Resize((128, 128)),  # 이미지 크기 조정
    transforms.ToTensor(),  # 이미지를 텐서로 변환
    transforms.Normalize(mean=[0.25, 0.25, 0.25], std=[0.1, 0.1, 0.1])  # 이미지 정규화
])


for image_path in test_path['image_path']:
    image = Image.open(image_path)
    tensor = transform(image)
    tensor_list_test.append(tensor)

image_tensors_test = torch.stack(tensor_list_test) #test데이터

# %%
X_train = image_tensors_train
y_train = train_data['label'].values
X_test = image_tensors_test
y_test = test_data['label'].values

# 데이터셋 생성
train_dataset = TensorDataset(X_train, torch.LongTensor(y_train))
test_dataset = TensorDataset(X_test, torch.LongTensor(y_test))

batch_size = 16  # 배치 크기 설정

# 데이터 로더 생성
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# DenseNet BottleNeck

class BottleNeck(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        inner_channels = 4 * growth_rate

        self.residual = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, inner_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(inner_channels),
            nn.ReLU(),
            nn.Conv2d(inner_channels, growth_rate, 3, stride=1, padding=1, bias=False)
        )

        self.shortcut = nn.Sequential()

    def forward(self, x):
        return torch.cat([self.shortcut(x), self.residual(x)], 1)

# %%
# Transition Block: 피쳐맵 크기와 채널 수 감소

class Transition(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.down_sample = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.AvgPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.down_sample(x)

# %%
# DenseNet

class DenseNet(nn.Module):
    def __init__(self, nblocks, growth_rate=12, reduction=0.5, num_classes=2, init_weights=True):
        super().__init__()

        self.growth_rate = growth_rate
        inner_channels = 2 * growth_rate # output channels of conv1 before entering Dense Block

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, inner_channels, 7, stride=2, padding=3),
            nn.MaxPool2d(3, 2, padding=1)
        )

        self.features = nn.Sequential()

        for i in range(len(nblocks)-1):
            self.features.add_module('dense_block_{}'.format(i), self._make_dense_block(nblocks[i], inner_channels))
            inner_channels += growth_rate * nblocks[i]
            out_channels = int(reduction * inner_channels)
            self.features.add_module('transition_layer_{}'.format(i), Transition(inner_channels, out_channels))
            inner_channels = out_channels 
        
        self.features.add_module('dense_block_{}'.format(len(nblocks)-1), self._make_dense_block(nblocks[len(nblocks)-1], inner_channels))
        inner_channels += growth_rate * nblocks[len(nblocks)-1]
        self.features.add_module('bn', nn.BatchNorm2d(inner_channels))
        self.features.add_module('relu', nn.ReLU())

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(inner_channels, num_classes)

        # weight initialization
        if init_weights:
            self._initialize_weights()
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.features(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    def _make_dense_block(self, nblock, inner_channels):
        dense_block = nn.Sequential()
        for i in range(nblock):
            dense_block.add_module('bottle_neck_layer_{}'.format(i), BottleNeck(inner_channels, self.growth_rate))
            inner_channels += self.growth_rate
        return dense_block

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def DenseNet_121():
    return DenseNet([6, 12, 24, 6])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = DenseNet_121()
model.to(device)
# Out:
# DenseNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (features): Sequential(
#     (dense_block_0): Sequential(
#       (bottle_neck_layer_0): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_1): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.001)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=8)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    #path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch+1, num_epochs, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            #torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':10,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_loader,
    'val_dl':test_loader,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler
    #'path2weights':'./models/weights.pt',
}

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 1/10, current lr= 0.001
# Copied best model weights!
# train loss: 0.152060, val loss: 0.066863, accuracy: 97.54, time: 57.4245 min
# ----------
# Epoch 2/10, current lr= 0.001
# Copied best model weights!
# train loss: 0.065930, val loss: 0.042247, accuracy: 98.66, time: 116.8199 min
# ----------
# Epoch 3/10, current lr= 0.001
# train loss: 0.046089, val loss: 0.045798, accuracy: 98.42, time: 178.7528 min
# ----------
# Epoch 4/10, current lr= 0.001
# Copied best model weights!
# train loss: 0.036619, val loss: 0.032844, accuracy: 98.88, time: 241.1263 min
# ----------
# Epoch 5/10, current lr= 0.001
# train loss: 0.030676, val loss: 0.035466, accuracy: 98.79, time: 302.2046 min
# ----------
# Epoch 6/10, current lr= 0.001
# Copied best model weights!
# train loss: 0.025353, val loss: 0.031508, accuracy: 98.98, time: 359.8706 min
# ----------
# Epoch 7/10, current lr= 0.001
# train loss: 0.022657, val loss: 0.036805, accuracy: 98.71, time: 412.1951 min
# ----------
# ...

# %%
# Train-Validation progress
num_epochs = params_train['num_epochs']

# plot loss progress
plt.title('Accuracy & Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train_loss')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='test_loss')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train_accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='test_accuracy')
plt.xlabel('Training Epochs')
plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
torch.save(model, './model/model2.pth')

# %%
# 메모리 정리
import gc

del image_tensors_test
del image_tensors_train

gc.collect()
